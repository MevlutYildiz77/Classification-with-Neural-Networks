# %%
import tensorflow as tf
#from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\TOSHIBA\Desktop\Projelerim\Classification-with-Neural-Networks\ClassificationWithNeuralNetworks.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Classification-with-Neural-Networks/ClassificationWithNeuralNetworks.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Classification-with-Neural-Networks/ClassificationWithNeuralNetworks.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> #from tensorflow import keras
#       <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Classification-with-Neural-Networks/ClassificationWithNeuralNetworks.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import numpy as np
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\tensorflow\__init__.py:469, in <module>
#     467 if hasattr(_current_module, "keras"):
#     468   try:
# --> 469     _keras._load()
#     470   except ImportError:
#     471     pass
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\tensorflow\python\util\lazy_loader.py:41, in LazyLoader._load(self)
#      39 """Load the module and insert it into the parent's globals."""
#      40 # Import the target module and insert it into the parent's namespace
# ---> 41 module = importlib.import_module(self.__name__)
#      42 self._parent_module_globals[self._local_name] = module
#      44 # Emit a warning if one was specified
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\models\__init__.py:18, in <module>
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\engine\functional.py:34, in <module>
#      32 from keras.engine import input_spec
#      33 from keras.engine import node as node_module
# ---> 34 from keras.engine import training as training_lib
#      35 from keras.engine import training_utils
#      36 from keras.saving.saved_model import json_utils
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\engine\training.py:33, in <module>
#      31 from keras.engine import base_layer
#      32 from keras.engine import base_layer_utils
# ---> 33 from keras.engine import compile_utils
#      34 from keras.engine import data_adapter
#      35 from keras.engine import input_layer as input_layer_module
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\engine\compile_utils.py:24, in <module>
#      21 import tensorflow.compat.v2 as tf
#      23 from keras import losses as losses_mod
# ---> 24 from keras import metrics as metrics_mod
#      25 from keras.saving.experimental import saving_lib
#      26 from keras.utils import generic_utils
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\metrics\__init__.py:33, in <module>
#      29 from keras.metrics.base_metric import clone_metrics
#      31 # Metric functions
#      32 # Individual metric classes
# ---> 33 from keras.metrics.metrics import AUC
#      34 from keras.metrics.metrics import Accuracy
#      35 from keras.metrics.metrics import BinaryAccuracy
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\metrics\metrics.py:28, in <module>
#      25 import numpy as np
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras import activations
#      29 from keras import backend
#      30 from keras.dtensor import utils as dtensor_utils
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\activations.py:21, in <module>
#      17 import sys
#      19 import tensorflow.compat.v2 as tf
# ---> 21 import keras.layers.activation as activation_layers
#      22 from keras import backend
#      23 from keras.utils import generic_utils
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\layers\__init__.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras.engine.base_layer import Layer
# ---> 20 from keras.engine.base_preprocessing_layer import PreprocessingLayer
#      22 # Generic layers.
#      23 from keras.engine.input_layer import Input
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\engine\base_preprocessing_layer.py:21, in <module>
#      17 import abc
#      19 import tensorflow.compat.v2 as tf
# ---> 21 from keras.engine import data_adapter
#      22 from keras.engine.base_layer import Layer
#      23 from keras.utils import version_utils
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\keras\engine\data_adapter.py:43, in <module>
#      40 from tensorflow.python.util.tf_export import keras_export
#      42 try:
# ---> 43     import pandas as pd
#      44 except ImportError:
#      45     pd = None
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\__init__.py:22, in <module>
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\compat\__init__.py:22, in <module>
#      17 from pandas._typing import F
#      18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
# ---> 22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#      25     pa_version_under3p0,
#      26     pa_version_under4p0,
#      27     pa_version_under5p0,
#      28     pa_version_under6p0,
#      29     pa_version_under7p0,
#      30     pa_version_under8p0,
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#      35     import lzma
#
# File c:\Users\TOSHIBA\anaconda3\envs\pythonProject\lib\site-packages\pandas\compat\pyarrow.py:10, in <module>
#       7 try:
#       8     import pyarrow as pa
# ---> 10     _pa_version = pa.__version__
#      11     _palv = Version(_pa_version)
#      12     pa_version_under1p01 = _palv < Version("1.0.1")
#
# AttributeError: module 'pyarrow' has no attribute '__version__'

# %%
fashion = keras.datasets.fashion_mnist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\TOSHIBA\Desktop\Projelerim\Classification-with-Neural-Networks\ClassificationWithNeuralNetworks.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/TOSHIBA/Desktop/Projelerim/Classification-with-Neural-Networks/ClassificationWithNeuralNetworks.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> fashion = keras.datasets.fashion_mnist
#
# NameError: name 'keras' is not defined
